# %% [markdown]
# # Bidirectional Recurrent Neural Networks
# :label:`sec_bi_rnn`
#
# So far, our working example of a sequence learning task has been language modeling,
# where we aim to predict the next token given all previous tokens in a sequence.
# In this scenario, we wish only to condition upon the leftward context,
# and thus the unidirectional chaining of a standard RNN seems appropriate.
# However, there are many other sequence learning tasks contexts
# where it is perfectly fine to condition the prediction at every time step
# on both the leftward and the rightward context.
# Consider, for example, part of speech detection.
# Why shouldn't we take the context in both directions into account
# when assessing the part of speech associated with a given word?
#
# Another common task---often useful as a pretraining exercise
# prior to fine-tuning a model on an actual task of interest---is
# to mask out random tokens in a text document and then to train
# a sequence model to predict the values of the missing tokens.
# Note that depending on what comes after the blank,
# the likely value of the missing token changes dramatically:
#
# * I am `___`.
# * I am `___` hungry.
# * I am `___` hungry, and I can eat half a pig.
#
# In the first sentence "happy" seems to be a likely candidate.
# The words "not" and "very" seem plausible in the second sentence,
# but "not" seems incompatible with the third sentences.
#
#
# Fortunately, a simple technique transforms any unidirectional RNN
# into a bidirectional RNN :cite:`Schuster.Paliwal.1997`.
# We simply implement two unidirectional RNN layers
# chained together in opposite directions
# and acting on the same input (:numref:`fig_birnn`).
# For the first RNN layer,
# the first input is $\mathbf{x}_1$
# and the last input is $\mathbf{x}_T$,
# but for the second RNN layer,
# the first input is $\mathbf{x}_T$
# and the last input is $\mathbf{x}_1$.
# To produce the output of this bidirectional RNN layer,
# we simply concatenate together the corresponding outputs
# of the two underlying unidirectional RNN layers.
#
#
# ![Architecture of a bidirectional RNN.](../img/birnn.svg)
# :label:`fig_birnn`
#
#
# Formally for any time step $t$,
# we consider a minibatch input $\mathbf{X}_t \in \mathbb{R}^{n \times d}$
# (number of examples $=n$; number of inputs in each example $=d$)
# and let the hidden layer activation function be $\phi$.
# In the bidirectional architecture,
# the forward and backward hidden states for this time step
# are $\overrightarrow{\mathbf{H}}_t  \in \mathbb{R}^{n \times h}$
# and $\overleftarrow{\mathbf{H}}_t  \in \mathbb{R}^{n \times h}$, respectively,
# where $h$ is the number of hidden units.
# The forward and backward hidden state updates are as follows:
#
#
# $$
# \begin{aligned}
# \overrightarrow{\mathbf{H}}_t &= \phi(\mathbf{X}_t \mathbf{W}_{\textrm{xh}}^{(f)} + \overrightarrow{\mathbf{H}}_{t-1} \mathbf{W}_{\textrm{hh}}^{(f)}  + \mathbf{b}_\textrm{h}^{(f)}),\\
# \overleftarrow{\mathbf{H}}_t &= \phi(\mathbf{X}_t \mathbf{W}_{\textrm{xh}}^{(b)} + \overleftarrow{\mathbf{H}}_{t+1} \mathbf{W}_{\textrm{hh}}^{(b)}  + \mathbf{b}_\textrm{h}^{(b)}),
# \end{aligned}
# $$
#
# where the weights $\mathbf{W}_{\textrm{xh}}^{(f)} \in \mathbb{R}^{d \times h}, \mathbf{W}_{\textrm{hh}}^{(f)} \in \mathbb{R}^{h \times h}, \mathbf{W}_{\textrm{xh}}^{(b)} \in \mathbb{R}^{d \times h}, \textrm{ and } \mathbf{W}_{\textrm{hh}}^{(b)} \in \mathbb{R}^{h \times h}$, and the biases $\mathbf{b}_\textrm{h}^{(f)} \in \mathbb{R}^{1 \times h}$ and $\mathbf{b}_\textrm{h}^{(b)} \in \mathbb{R}^{1 \times h}$ are all the model parameters.
#
# Next, we concatenate the forward and backward hidden states
# $\overrightarrow{\mathbf{H}}_t$ and $\overleftarrow{\mathbf{H}}_t$
# to obtain the hidden state $\mathbf{H}_t \in \mathbb{R}^{n \times 2h}$ for feeding into the output layer.
# In deep bidirectional RNNs with multiple hidden layers,
# such information is passed on as *input* to the next bidirectional layer.
# Last, the output layer computes the output
# $\mathbf{O}_t \in \mathbb{R}^{n \times q}$ (number of outputs $=q$):
#
# $$\mathbf{O}_t = \mathbf{H}_t \mathbf{W}_{\textrm{hq}} + \mathbf{b}_\textrm{q}.$$
#
# Here, the weight matrix $\mathbf{W}_{\textrm{hq}} \in \mathbb{R}^{2h \times q}$
# and the bias $\mathbf{b}_\textrm{q} \in \mathbb{R}^{1 \times q}$
# are the model parameters of the output layer.
# While technically, the two directions can have different numbers of hidden units,
# this design choice is seldom made in practice.
# We now demonstrate a simple implementation of a bidirectional RNN.

# %%
import torch
from torch import nn
from d2l import torch as d2l

# %% [markdown]
# ## Implementation from Scratch
#
# To implement a bidirectional RNN from scratch, we can
# include two unidirectional `RNNScratch` instances
# with separate learnable parameters.

# %%
class BiRNNScratch(d2l.Module):
    def __init__(self, num_inputs, num_hiddens, sigma=0.01):
        super().__init__()
        self.save_hyperparameters()
        self.f_rnn = d2l.RNNScratch(num_inputs, num_hiddens, sigma)
        self.b_rnn = d2l.RNNScratch(num_inputs, num_hiddens, sigma)
        self.num_hiddens *= 2  # The output dimension will be doubled

# %% [markdown]
# States of forward and backward RNNs
# are updated separately,
# while outputs of these two RNNs are concatenated.

# %%
@d2l.add_to_class(BiRNNScratch)
def forward(self, inputs, Hs=None):
    f_H, b_H = Hs if Hs is not None else (None, None)
    f_outputs, f_H = self.f_rnn(inputs, f_H)
    b_outputs, b_H = self.b_rnn(reversed(inputs), b_H)
    outputs = [torch.cat((f, b), -1) for f, b in zip(
        f_outputs, reversed(b_outputs))]
    return outputs, (f_H, b_H)

# %% [markdown]
# ## Concise Implementation

# %% [markdown]
# Using the high-level APIs,
# we can implement bidirectional RNNs more concisely.
# Here we take a GRU model as an example.

# %%
class BiGRU(d2l.RNN):
    def __init__(self, num_inputs, num_hiddens):
        d2l.Module.__init__(self)
        self.save_hyperparameters()
        self.rnn = nn.GRU(num_inputs, num_hiddens, bidirectional=True)
        self.num_hiddens *= 2

# %% [markdown]
# ## Summary
#
# In bidirectional RNNs, the hidden state for each time step is simultaneously determined by the data prior to and after the current time step. Bidirectional RNNs are mostly useful for sequence encoding and the estimation of observations given bidirectional context. Bidirectional RNNs are very costly to train due to long gradient chains.
#
# ## Exercises
#
# 1. If the different directions use a different number of hidden units, how will the shape of $\mathbf{H}_t$ change?
# 1. Design a bidirectional RNN with multiple hidden layers.
# 1. Polysemy is common in natural languages. For example, the word "bank" has different meanings in contexts “i went to the bank to deposit cash” and “i went to the bank to sit down”. How can we design a neural network model such that given a context sequence and a word, a vector representation of the word in the correct context will be returned? What type of neural architectures is preferred for handling polysemy?

# %% [markdown]
# [Discussions](https://discuss.d2l.ai/t/1059)

# %% [markdown]
# I'll provide a comprehensive answer about handling polysemy in neural network models with the appropriate architectural approaches.
#
# ```markdown
# # Handling Polysemy in Neural Language Models
#
# ## Understanding the Problem
#
# **Polysemy** refers to words having multiple distinct meanings depending on their context. For example, "bank" can refer to:
# - A financial institution ("I went to the bank to deposit cash")
# - The side of a river ("I went to the bank to sit down")
#
# Traditional word embeddings like Word2Vec and GloVe struggle with polysemy because they assign a single static vector to each word, regardless of context. This means "bank" would have the same representation in both sentences, conflating its different meanings.
#
# ## Designing Context-Aware Word Representations
#
# To return a vector representation of a word that reflects its correct context-specific meaning, we need models that produce dynamic, context-dependent word embeddings.
#
# ### Key Architectural Components
#
# 1. **Contextual Encoder**: Process the entire sentence to understand context
# 2. **Dynamic Embedding Generator**: Generate word representations conditioned on context
# 3. **Disambiguation Mechanism**: Differentiate between different senses of the same word
#
# ## Preferred Neural Architectures for Polysemy
#
# ### 1. Bidirectional Recurrent Neural Networks
#
# **Architecture:**
# - Bi-directional LSTMs or GRUs encode the full sentence
# - Word representation is derived from hidden states at the word's position
#
# **Mechanism:**
# ```python
# class BiRNNForPolysemy(nn.Module):
#     def __init__(self, vocab_size, embedding_dim, hidden_dim):
#         super().__init__()
#         self.embedding = nn.Embedding(vocab_size, embedding_dim)
#         self.bi_lstm = nn.LSTM(embedding_dim, hidden_dim // 2, bidirectional=True)
#
#     def forward(self, sentence):
#         embeddings = self.embedding(sentence)  # [seq_len, batch, embed_dim]
#         outputs, _ = self.bi_lstm(embeddings)  # [seq_len, batch, hidden_dim]
#         return outputs  # Contextual word representations
# ```
#
# **Advantages:**
# - Captures both left and right context for each word
# - Relatively simple architecture
#
# **Limitations:**
# - Limited context window due to vanishing gradients
# - Less effective for long-range dependencies
#
# ### 2. Transformer-Based Models (Preferred Architecture)
#
# **Architecture:**
# - Self-attention mechanisms to model relationships between all words
# - Each word's representation is influenced by every other word in the sentence
#
# **Mechanism:**
# ```python
# class TransformerForPolysemy(nn.Module):
#     def __init__(self, vocab_size, embedding_dim, nhead, num_layers):
#         super().__init__()
#         self.embedding = nn.Embedding(vocab_size, embedding_dim)
#         self.positional_encoding = PositionalEncoding(embedding_dim)
#         encoder_layer = nn.TransformerEncoderLayer(embedding_dim, nhead)
#         self.transformer = nn.TransformerEncoder(encoder_layer, num_layers)
#
#     def forward(self, sentence):
#         embeddings = self.embedding(sentence)  # [seq_len, batch, embed_dim]
#         embeddings = self.positional_encoding(embeddings)
#         contextual_representations = self.transformer(embeddings)  # [seq_len, batch, embed_dim]
#         return contextual_representations
# ```
#
# **Advantages:**
# - Captures global context through self-attention
# - Excellent at modeling long-range dependencies
# - State-of-the-art performance on word sense disambiguation tasks
# - Can be pre-trained on large corpora (BERT, RoBERTa, etc.)
#
# ### 3. ELMo (Embeddings from Language Models)
#
# **Architecture:**
# - Multi-layer bidirectional LSTM
# - Word representation is a learned weighted combination of all layer representations
#
# **Mechanism:**
# ```python
# class ELMoForPolysemy(nn.Module):
#     def __init__(self, vocab_size, embedding_dim, hidden_dim, num_layers):
#         super().__init__()
#         self.embedding = nn.Embedding(vocab_size, embedding_dim)
#         self.lstm_layers = nn.ModuleList([
#             nn.LSTM(embedding_dim if i == 0 else hidden_dim, hidden_dim // 2, bidirectional=True)
#             for i in range(num_layers)
#         ])
#         self.weights = nn.Parameter(torch.ones(num_layers))
#         self.scalar = nn.Parameter(torch.tensor(1.0))
#
#     def forward(self, sentence):
#         embeddings = self.embedding(sentence)
#         layer_outputs = []
#
#         current_output = embeddings
#         for lstm in self.lstm_layers:
#             current_output, _ = lstm(current_output)
#             layer_outputs.append(current_output)
#
#         # Softmax normalization of layer weights
#         norm_weights = F.softmax(self.weights, dim=0)
#
#         # Weighted combination of layer representations
#         weighted_sum = sum(w * h for w, h in zip(norm_weights, layer_outputs))
#         return self.scalar * weighted_sum  # Final contextual word representations
# ```
#
# **Advantages:**
# - Different layers capture different linguistic aspects (syntax vs. semantics)
# - Adaptive weighting of representations
#
# ### 4. BERT and Other Pre-trained Transformers
#
# **Architecture:**
# - Multi-head self-attention with deep bidirectional context
# - Contextual representations pre-trained with masked language modeling
#
# **Implementation approach:**
# ```python
# from transformers import BertModel, BertTokenizer
#
# class BERTForPolysemy:
#     def __init__(self):
#         self.tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
#         self.model = BertModel.from_pretrained('bert-base-uncased')
#
#     def get_contextual_embedding(self, sentence, target_word_index):
#         inputs = self.tokenizer(sentence, return_tensors='pt')
#         outputs = self.model(**inputs)
#
#         # Extract the contextual representation of the target word
#         word_vector = outputs.last_hidden_state[0, target_word_index]
#         return word_vector
# ```
#
# **Advantages:**
# - Pre-trained on massive datasets
# - Multiple attention heads capture different semantic relationships
# - Excellent performance with fine-tuning for specific tasks
#
# ## Extracting the Word Representation in Context
#
# To get a specific word's contextualized representation from these models:
#
# ```python
# def get_word_in_context(model, sentence, target_word_position):
#     """Extract the contextual representation of a target word."""
#     # Tokenize the sentence
#     tokenized_sentence = tokenize(sentence)
#
#     # Get contextual representations for all words
#     contextual_representations = model(tokenized_sentence)
#
#     # Extract representation at the target position
#     target_representation = contextual_representations[target_word_position]
#
#     return target_representation
# ```
#
# ## Evaluating Polysemy Handling
#
# We can evaluate if our model correctly handles polysemy by:
#
# 1. Word Sense Disambiguation (WSD) tasks
# 2. Semantic similarity of contextualized representations
# 3. Visualization of embeddings for the same word in different contexts (using t-SNE)
#
# ```python
# # Example of showing that "bank" gets different representations in different contexts
# contexts = [
#     "I went to the bank to deposit cash",
#     "I went to the bank to sit down"
# ]
#
# bank_vectors = []
# for context in contexts:
#     # Tokenize and find position of "bank"
#     tokens = tokenize(context)
#     bank_position = tokens.index("bank")
#
#     # Get contextualized representation
#     contextual_representations = model(tokens)
#     bank_vector = contextual_representations[bank_position]
#     bank_vectors.append(bank_vector)
#
# # Compute similarity between the two representations
# similarity = cosine_similarity(bank_vectors[0], bank_vectors[1])
# print(f"Similarity between 'bank' in different contexts: {similarity}")
# # Should be lower than similarity between same-sense usages
# ```
#
# ## Conclusion
#
# For handling polysemy effectively, transformer-based architectures (particularly BERT, RoBERTa, or their variants) are currently preferred due to their superior ability to model contextual relationships. These models dynamically generate word representations based on the surrounding context, allowing the same word to have different vector representations that accurately reflect its intended meaning in each specific context.
#
# The key advantage of transformers over RNNs for polysemy is their ability to directly model relationships between any words in the sequence through self-attention, regardless of their distance from each other, which is crucial for accurate word sense disambiguation.
# ```
